# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


data_galaxies = 'Milky way', 'Ursa III', 'Sagittarius', 'Large Magellanic Cloud', 'Small Magellanic Cloud'

value_galaxies = 100, 200, 300, 400, 500 # Added 500 to match the number of galaxies

print(data_galaxies)
print(value_galaxies)

plt.figure(figsize=(15, 10))
plt.bar(data_galaxies, value_galaxies)
plt.show()
# Out:
# ('Milky way', 'Ursa III', 'Sagittarius', 'Large Magellanic Cloud', 'Small Magellanic Cloud')
# (100, 200, 300, 400, 500)
